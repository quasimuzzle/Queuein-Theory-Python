# %% [markdown]
# ## scipy.stats.expon
# ### Экспоненциальное распределение

# %%
import numpy as np
from scipy.stats import expon
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
mean, var, skew, kurt = expon.stats(moments='mvsk')
# функция плотности вероятности
x = np.linspace(expon.ppf(0.01),
                expon.ppf(0.99), 100)
ax.plot(x, expon.pdf(x),
       'r-', lw=5, alpha=0.6, label='expon pdf')

# %% [markdown]
# Генерация рандомных значение
#
# ### rvs(loc=0, scale=1, size=1, random_state=None)

# %%
a = expon.rvs(scale = 8, size = 20)
plt.hist(a, density= True)
# Out:
# (array([0.09164779, 0.09164779, 0.01309254, 0.02618508, 0.        ,
#         0.01309254, 0.01309254, 0.        , 0.        , 0.01309254]),
#  array([ 0.25601249,  4.07498087,  7.89394925, 11.71291762, 15.531886  ,
#         19.35085437, 23.16982275, 26.98879113, 30.8077595 , 34.62672788,
#         38.44569626]),
#  <BarContainer object of 10 artists>)

# %%
a2 = expon.rvs(scale = 8, size = 200)
plt.hist(a2, density= True)
# Out:
# (array([0.11039935, 0.07049597, 0.02793237, 0.01995169, 0.01862158,
#         0.00798068, 0.00532045, 0.00266023, 0.00133011, 0.00133011]),
#  array([2.58663713e-02, 3.78494632e+00, 7.54402627e+00, 1.13031062e+01,
#         1.50621862e+01, 1.88212661e+01, 2.25803461e+01, 2.63394260e+01,
#         3.00985060e+01, 3.38575859e+01, 3.76166659e+01]),
#  <BarContainer object of 10 artists>)

# %%
a3 = expon.rvs(scale = 2, size = 5)
plt.hist(a3, density= True)
# Out:
# (array([2.39536395, 0.        , 0.        , 0.        , 1.19768197,
#         0.        , 0.        , 0.        , 1.19768197, 1.19768197]),
#  array([0.11931907, 0.28630831, 0.45329754, 0.62028678, 0.78727602,
#         0.95426526, 1.1212545 , 1.28824373, 1.45523297, 1.62222221,
#         1.78921145]),
#  <BarContainer object of 10 artists>)
