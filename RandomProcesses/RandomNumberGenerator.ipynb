# %%
import numpy as np 
import matplotlib.pyplot as plt
from math import log,pi,cos,sin,sqrt

t = 0.001
max_t = 1
s = np.random.uniform(0, 1 , 1000)
normal = [0 for i in range(int(max_t/t))]
x = [i*t for i in range(int(max_t/t))]

count, bins, ignored = plt.hist(s, 15, density = True)
plt.plot(bins, np.ones_like(bins), linewidth = 2, color = 'r')


u = -1
temp = np.random.uniform(0, 1, 12000)

pre_normal = [sum(temp[12*i:12*i+12]) for i in range(0, 1000, 1)]
exp_dist = [0 for i in range(0, 1000, 1)]
for i in range (0, 1000, 1):
    normal[i] = pre_normal[i]-6
    exp_dist[i] = -log(s[i])
    
exp_dist.sort()    
plt.hist(normal)
plt.figure()
plt.plot(x, np.random.normal(0, 1, 1000))
plt.figure()
plt.hist( exp_dist)
plt.show()
